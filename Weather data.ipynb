# %%
import pandas as pd
from zipfile import ZipFile
import matplotlib.pyplot as plt
import os

# %%
path = '\2. Semester\DLR\Data\klarchiv_00003_daily_his.zip'
#ZipFile.extract(path, )

# %%
#df = pd.read_csv('Data/TitanicTrain.csv')

# %%
# import os

# with ZipFile('Data/klarchiv_00003_daily_his.zip') as z:
#     with open('Data/', 'wb') as f:
#         f.write(z.read('/produkt_klima_tag_18910101_20110331_00003.txt'))


# file = 'Weather_DataSet/klarchiv_00003_daily_his.zip'
 
# # opening the zip file in READ mode
# with ZipFile(file, 'r') as zip: 
#     # printing all the contents of the zip file 
#     zip.printdir()
  
#     # extracting all the files
#     print('Extracting all the files now...')
#     zip.extractall('Data/Unzipped/')
#     print('Done!')

# %%
data = pd.read_csv('Weather_DataSet/klarchiv_00003_daily_his/produkt_klima_tag_18910101_20110331_00003.txt', sep=';')
data.head(20)
# Out:
#     STATIONS_ID  MESS_DATUM  QN_3     FX     FM  QN_4   RSK  RSKF    SDK  \
# 0             3    18910101  -999 -999.0 -999.0     5   0.0     0 -999.0
# 1             3    18910102  -999 -999.0 -999.0     5   0.0     0 -999.0
# 2             3    18910103  -999 -999.0 -999.0     5   2.5     1 -999.0
# 3             3    18910104  -999 -999.0 -999.0     5   8.2     1 -999.0
# 4             3    18910105  -999 -999.0 -999.0     5   1.9     1 -999.0
# 5             3    18910106  -999 -999.0 -999.0     5   2.5     1 -999.0
# 6             3    18910107  -999 -999.0 -999.0     5   2.9     1 -999.0
# 7             3    18910108  -999 -999.0 -999.0     5   0.0     0 -999.0
# 8             3    18910109  -999 -999.0 -999.0     5   0.0     0 -999.0
# 9             3    18910110  -999 -999.0 -999.0     5   0.0     0 -999.0
# 10            3    18910111  -999 -999.0 -999.0     5   0.0     0 -999.0
# 11            3    18910112  -999 -999.0 -999.0     5   6.6     1 -999.0
# 12            3    18910113  -999 -999.0 -999.0     5   0.0     0 -999.0
# 13            3    18910114  -999 -999.0 -999.0     5   1.1     1 -999.0
# 14            3    18910115  -999 -999.0 -999.0     5   3.1     1 -999.0
# 15            3    18910116  -999 -999.0 -999.0     5   0.9     1 -999.0
# 16            3    18910117  -999 -999.0 -999.0     5   2.1     1 -999.0
# 17            3    18910118  -999 -999.0 -999.0     5   2.2     1 -999.0
# 18            3    18910119  -999 -999.0 -999.0     5   0.0     0 -999.0
# 19            3    18910120  -999 -999.0 -999.0     5  11.1     1 -999.0
#
#     SHK_TAG    NM   VPM     PM   TMK   UPM   TXK   TNK    TGK  eor
# 0      -999   0.0   4.3 -999.0  -3.6  88.0   0.5  -5.9 -999.0  eor
# 1      -999   2.7   4.1 -999.0  -2.8  84.0   0.0  -5.8 -999.0  eor
# 2      -999   3.7   3.9 -999.0  -0.2  69.0   2.1  -6.2 -999.0  eor
# 3      -999   8.0   6.4 -999.0   1.8  90.0   3.7   0.6 -999.0  eor
# 4      -999   7.7   4.7 -999.0  -2.5  87.0   1.5  -4.2 -999.0  eor
# 5      -999   8.0   3.5 -999.0  -5.8  88.0  -4.0  -6.9 -999.0  eor
# 6      -999   8.0   3.6 -999.0  -5.8  94.0  -5.0  -7.7 -999.0  eor
# 7      -999   6.7   3.7 -999.0  -5.0  89.0  -3.5  -5.7 -999.0  eor
# 8      -999   6.7   2.9 -999.0  -7.8  87.0  -4.7  -9.2 -999.0  eor
# 9      -999   3.7   2.1 -999.0 -11.4  85.0  -7.6 -12.7 -999.0  eor
# 10     -999   4.0   3.1 -999.0  -7.2  88.0  -5.6 -12.6 -999.0  eor
# 11     -999   8.0   5.1 -999.0   0.2  87.0   1.2  -5.8 -999.0  eor
# 12     -999   2.7   5.6 -999.0   0.4  86.0   2.8  -0.8 -999.0  eor
# 13     -999   6.7   5.3 -999.0   0.4  83.0   1.9  -2.3 -999.0  eor
# 14     -999   5.0   4.0 -999.0  -3.8  85.0   0.2  -5.0 -999.0  eor
# 15     -999   5.7   2.9 -999.0  -7.8  85.0  -4.0 -10.7 -999.0  eor
# 16     -999   6.0   2.0 -999.0 -12.2  87.0  -8.0 -13.8 -999.0  eor
# 17     -999   8.0   3.6 -999.0  -6.0  94.0  -5.0 -12.4 -999.0  eor
# 18     -999   6.0   3.7 -999.0  -6.2  94.0  -4.0  -7.7 -999.0  eor
# 19     -999   6.0   3.7 -999.0  -4.2  87.0  -1.6 -10.2 -999.0  eor

# %%
data = pd.read_csv('Weather_DataSet/klarchiv_00003_daily_his/produkt_klima_tag_18910101_20110331_00003.txt', sep=';')
data.head(20)

#data['  FM'].unique()

# data['  FM'].value_counts().plot.bar()
# plt.show()

data_all = pd.DataFrame()

#Initialize path
path = 'Weather_DataSet/klarchiv_01078_daily_his'
directory = os.fsencode(path)

path2 ='Weather_DataSet/'
directory2= os.fsencode(path2)

for dir in os.listdir(directory2):
    for file in os.listdir(directory):
         filename = os.fsdecode(file)
         if filename.startswith("produkt_klima_tag"): 
            filepath = path + '/' + filename 
            data = pd.read_csv(filepath, sep=';')
            data = data[(data['MESS_DATUM']>=20160101)&(data['MESS_DATUM']<=20171231)]
            data_all.append(data)
            #print(data)
         else:
             pass

data_all.head()

# data_small = data[(data['MESS_DATUM']>=20100101)&(data['MESS_DATUM']<=20110101)]
# data_small.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import os
rootdir = 'Weather_data'

for subdir, dirs, files in os.walk(rootdir):
    for file in files:
         if filename.startswith("produkt_klima_tag"): 
            #filepath = path + '/' + filename 
            data = pd.read_csv(os.path.join(subdir, file), sep=';', encoding='ISO-8859-1')
            data = data[(data['MESS_DATUM']>=20160101)&(data['MESS_DATUM']<=20171231)]
            #data_all.append(data)
            #print(data)
#            print(os.path.join(subdir, file)).replace("\","/")

# %%
a = 'hello'
b = 'world'
c = a +b
c

# %%
data = pd.read_csv('Data/Unzipped/Metadaten_Stationsname_00003.txt', sep=';')
data.head(20)

# %%
data = pd.read_csv('Data/Unzipped/Metadaten_Parameter_klima_tag_00003.txt', sep=';', encoding='ISO-8859-1')
data.head(20)
meta = data.drop_duplicates('Parameter')
meta.head(30)

# %%
data = pd.read_csv('Data/Unzipped/Metadaten_Geographie_00003.txt', sep=';')
data.head(20)
